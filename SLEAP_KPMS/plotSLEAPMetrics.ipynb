# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from sleap_nn.evaluation import load_metrics, Evaluator
from pathlib import Path
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_119620\2219524577.py in <module>
#       4 import matplotlib.pyplot as plt
#       5 import seaborn as sns
# ----> 6 from sleap_nn.evaluation import load_metrics, Evaluator
#       7 from pathlib import Path
#
# ModuleNotFoundError: No module named 'sleap_nn'

# %%
help(load_metrics)

# %%
import sleap_nn

metrics = sleap_nn.evaluation.load_metrics("td_fast.centered_instance.n=1800/train_0_pred_metrics.npz")
print("\n".join(metrics.keys()))

# %%
import numpy as np
data = np.load(r"\\smith-nas.ucsd.edu\Lab\SLEAP\models\bottom-up_9ptskeleton\250730_221413.multi_instance.n=1291_v12_bottomup\metrics.train.npz", allow_pickle=True)
data.files
data['metrics'].shape
# Out:
# ()

# %%
np.savetxt("data.csv", arr, delimiter=",")
